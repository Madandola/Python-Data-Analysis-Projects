# %% [markdown]
# <a href="https://colab.research.google.com/github/Madandola/Python-Data-Analysis-Projects/blob/main/Day_1_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is another title section

# %% [markdown]
# ## This is the sub-section of the title

# %% [markdown]
# # This is the title of the section

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
print("kolawole")
# Out:
# kolawole

# %%
print(3.14)
# Out:
# 3.14

# %%
print(30*3)
# Out:
# 90

# %%
print("mt father's favourite car is toyota")
# Out:
# mt father's favourite car is toyota

# %%
print('My father\'s favourite car is Toyota')
# Out:
# My father's favourite car is Toyota

# %%
print("The itsy bitsy spider\nclimbed up the waterspout.")

print()

print("Down came the rain\nand washed the spider out.")
# Out:
# The itsy bitsy spider
# climbed up the waterspout.
#
# Down came the rain
# and washed the spider out.

# %%
print(len("I am learning Python"))
# Out:
# 20

# %%
print("\\")

print("2" + "3")

print(2 + 3)

print("2" + "3")

print(2 + 3)
# Out:
# \
# 23
# 5
# 23
# 5

# %% [markdown]
# # When used between string objects, + will behave like concatenation operator
#
# ## When used between numeric objects, + will behave like arithmetic operator

# %%
print("2", "3")

print("2", 3, True, 3.14)
# Out:
# 2 3
# 2 3 True 3.14

# %%
print("2", 3, True, 3.14)
# this is an example of multiple arguments in Python
# Out:
# 2 3 True 3.14

# %%
# this is an example of multiple arguments in Python
print("I" + "am"+"learning"+"Python")
# Out:
# IamlearningPython

# %%
my_name = "Kolawole"
print (my_name)
# Out:
# Kolawole

# %%
my_age =33
your_age =30
my_age=your_age # In this step value of your_age will be assigned to my age
print(my_age)
# Out:
# 30

# %% [markdown]
# ## Name rules
#
#
#
# 1.  Dont start with numbers
# 2.  Dont use space in variable name
# 3.  Dont start with uppercase
# 4.  You can only use_

# %% [markdown]
# ##Input ()function

# %%
b= 10
print(b)
# Out:
# 10

# %%
# simple calculator
print("This is a simple calculator.")
# convert results of input function to integers
number1 = float(input("Enter the first number: ")) # input converted to float
number2 = float(input("Enter the second number: ")) # input converted to float
# float type conversion is safer. Because int function cant convert float to integer

print(number1, "added to", number2, "is", number1+number2)
# Out:
# This is a simple calculator.
# Enter the first number: 5
# Enter the second number: 2
# 5.0 added to 2.0 is 7.0

# %%
# simple calculator
print("This is a simple calculator.")
number1 = input("Enter the first number: ")
number2 = input("Enter the second number: ")

print(number1, "added to", number2, "is", number1+number2)
# Out:
# This is a simple calculator.
# Enter the first number: 2
# Enter the second number: 6
# 2 added to 6 is 26

# %%
# simple calculator
print("This is a simple calculator.")
# convert results of input function to integers
number1 = float(input("Enter the first number: ")) # input converted to float
number2 = float(input("Enter the second number: ")) # input converted to float
# float type conversion is safer. Because int function cant convert float to integer

print(number1, "added to", number2, "is", number1+number2)
# Out:
# This is a simple calculator.
# Enter the first number: 2
# Enter the second number: 14
# 2.0 added to 14.0 is 16.0

# %%
# simple calculator
print("This is a simple calculator.")
# convert results of input function to integers
number1 = float(input("Enter the first number: ")) # input converted to float
number2 = float(input("Enter the second number: ")) # input converted to float
# float type conversion is safer. Because int function cant convert float to integer

print(number1, "added to", number2, "is", number1+number2)

print(number1, "divided by", number2, "is", number1/number2)

print(number1, "multiply by", number2, "is", number1*number2)
# Out:
# This is a simple calculator.
# Enter the first number: 2
# Enter the second number: 78
# 2.0 added to 78.0 is 80.0
# 2.0 divided by 78.0 is 0.02564102564102564
# 2.0 multiply by 78.0 is 156.0
